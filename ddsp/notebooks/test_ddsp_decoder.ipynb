# %% [markdown]
# # Setup

# %% [markdown]
# set working directory to guitarist-net and add to path

# %%
# %cd /content/drive/Othercomputers/My MacBook Pro/guitarist-net
# Out:
# /content/drive/Othercomputers/My MacBook Pro/guitarist-net

# %% [markdown]
# install requirements

# %%
# !pip install -r requirements.txt &> /dev/null

# %% [markdown]
# imports

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from plot_listen.listen import play
from plot_listen.plot import plot
import librosa.display
from globals import *
from ddsp.mlp import MLP
from ddsp.ddsp_decoder import DDSPDecoder

# %% [markdown]
# # Test MLP

# %%
mlp = MLP()

# %%
print(mlp)
# Out:
# MLP(
#   (model): Sequential(
#     (0): Linear(in_features=1, out_features=512, bias=True)
#     (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (2): ReLU()
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (5): ReLU()
#     (6): Linear(in_features=512, out_features=512, bias=True)
#     (7): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (8): ReLU()
#   )
# )

# %% [markdown]
# # Test Decoder

# %%
decoder = DDSPDecoder()

# %%
print(decoder)
# Out:
# DDSPDecoder(
#   (mlp_f0): MLP(
#     (model): Sequential(
#       (0): Linear(in_features=1, out_features=512, bias=True)
#       (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (2): ReLU()
#       (3): Linear(in_features=512, out_features=512, bias=True)
#       (4): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (5): ReLU()
#       (6): Linear(in_features=512, out_features=512, bias=True)
#       (7): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (8): ReLU()
#     )
#   )
#   (mlp_loudness): MLP(
#     (model): Sequential(
#       (0): Linear(in_features=1, out_features=512, bias=True)
#       (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (2): ReLU()
#       (3): Linear(in_features=512, out_features=512, bias=True)
#       (4): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (5): ReLU()
#       (6): Linear(in_features=512, out_features=512, bias=True)
#       (7): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (8): ReLU()
#     )
#   )
#   (gru): GRU(1024, 512, batch_first=True, bidirectional=True)
#   (final_mlp): MLP(
#     (model): Sequential(
#       (0): Linear(in_features=2048, out_features=512, bias=True)
#       (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (2): ReLU()
#       (3): Linear(in_features=512, out_features=512, bias=True)
#       (4): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (5): ReLU()
#       (6): Linear(in_features=512, out_features=512, bias=True)
#       (7): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (8): ReLU()
#     )
#   )
#   (dense_amplitudes): Linear(in_features=512, out_features=129, bias=True)
#   (dense_filter_coeffs): Linear(in_features=512, out_features=128, bias=True)
# )

# %%
from torchsummary import summary

# %%
summary(decoder, [(1000,), (1000,)])
# Out:
# in decoder forward
# before gru
# after gru
# after final mlp
# after dense layers
# after softmax
# after store in dict
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1            [-1, 1000, 512]           1,024
#          LayerNorm-2            [-1, 1000, 512]           1,024
#               ReLU-3            [-1, 1000, 512]               0
#             Linear-4            [-1, 1000, 512]         262,656
#          LayerNorm-5            [-1, 1000, 512]           1,024
#               ReLU-6            [-1, 1000, 512]               0
#             Linear-7            [-1, 1000, 512]         262,656
#          LayerNorm-8            [-1, 1000, 512]           1,024
#               ReLU-9            [-1, 1000, 512]               0
#               MLP-10            [-1, 1000, 512]               0
#            Linear-11            [-1, 1000, 512]           1,024
#         LayerNorm-12            [-1, 1000, 512]           1,024
#              ReLU-13            [-1, 1000, 512]               0
#            Linear-14            [-1, 1000, 512]         262,656
#         LayerNorm-15            [-1, 1000, 512]           1,024
#              ReLU-16            [-1, 1000, 512]               0
#            Linear-17            [-1, 1000, 512]         262,656
#         LayerNorm-18            [-1, 1000, 512]           1,024
#              ReLU-19            [-1, 1000, 512]               0
#               MLP-20            [-1, 1000, 512]               0
#               GRU-21  [[-1, 1000, 1024], [-1, 2, 512]]               0
#            Linear-22            [-1, 1000, 512]       1,049,088
#         LayerNorm-23            [-1, 1000, 512]           1,024
#              ReLU-24            [-1, 1000, 512]               0
#            Linear-25            [-1, 1000, 512]         262,656
#         LayerNorm-26            [-1, 1000, 512]           1,024
#              ReLU-27            [-1, 1000, 512]               0
#            Linear-28            [-1, 1000, 512]         262,656
#         LayerNorm-29            [-1, 1000, 512]           1,024
#              ReLU-30            [-1, 1000, 512]               0
#               MLP-31            [-1, 1000, 512]               0
#            Linear-32            [-1, 1000, 129]          66,177
#            Linear-33            [-1, 1000, 128]          65,664
# ================================================================
# Total params: 2,768,129
# Trainable params: 2,768,129
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 3.81
# Forward/backward pass size (MB): 7880.85
# Params size (MB): 10.56
# Estimated Total Size (MB): 7895.23
# ----------------------------------------------------------------

# %% [markdown]
# try sending dummy input through

# %%
dummy_f0 = torch.zeros((32, 1000))
dummy_loudness = torch.zeros((32, 1000))

# %%
p = decoder(dummy_f0, dummy_loudness)
# Out:
# in decoder forward
# before gru
# after gru
# after final mlp
# after dense layers
# after softmax
# after store in dict

# %%
print(p['f0'].shape)
print(p['overall_amplitude'].shape)
print(p['harm_distr'].shape)
# Out:
# torch.Size([32, 1000])
# torch.Size([32, 1000])
# torch.Size([32, 1000, 128])

# %% [markdown]
# # Feed into noise + harmonic synths

# %%
from ddsp.filtered_noise import FilteredNoise
from ddsp.harmonic_oscillator import HarmonicOscillator

# %%
noise_synth = FilteredNoise()
harm_synth = HarmonicOscillator()

# %%
noise_audio = noise_synth(p)

# %%
play(noise_audio.detach().numpy()[0])
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
harmonic_audio = harm_synth(p)
