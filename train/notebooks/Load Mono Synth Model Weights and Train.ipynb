# %% [markdown]
# # Setup

# %% [markdown]
# set working directory to guitarist-net and add to path

# %%
# %cd /content/drive/Othercomputers/My MacBook Pro/guitarist-net
# Out:
# /content/drive/Othercomputers/My MacBook Pro/guitarist-net

# %% [markdown]
# install requirements

# %%
# !pip install -r requirements.txt &> /dev/null

# %% [markdown]
# imports

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from plot_listen.listen import play
from plot_listen.plot import plot
from globals import *
from data.single_string_dataset import SingleStringDataset
from ddsp.ddsp_mono_synth import DDSPMonoSynth
from train.model_trainer import ModelTrainer

# %% [markdown]
# # Set up Training

# %% [markdown]
# get datasets

# %%
train_dataset = SingleStringDataset()
# Out:
# Type a number to select an option:
# 	0)	test_player-00_e-string.npz
# 	1)	train_player-not00_e-string.npz
# 	2)	test_player-00_E-string.npz
# 	3)	train_player-not00_E-string.npz
# 	4)	test_player-00_solo_E-string.npz
# 	5)	train_player-not00_solo_E-string.npz
# 	6)	test_player-00_solo_e-string.npz
# 	7)	train_player-not00_solo_e-string.npz
# 	8)	test_player-00_solo_e-string_1.0s_crepe.npz
# 	9)	train_player-not00_solo_e-string_1.0s_crepe.npz
# 	10)	test_player-00_solo_B-string_1.0s_crepe.npz
# 	11)	train_player-not00_solo_B-string_1.0s_crepe.npz
# 	12)	test_player-00_solo_G-string_1.0s_crepe.npz
# 	13)	train_player-not00_solo_G-string_1.0s_crepe.npz
# 	14)	test_player-00_solo_D-string_1.0s_crepe.npz
# 	15)	train_player-not00_solo_D-string_1.0s_crepe.npz
# 	16)	test_player-00_solo_A-string_1.0s_crepe.npz
# 	17)	train_player-not00_solo_A-string_1.0s_crepe.npz
# 	18)	test_player-00_solo_E-string_1.0s_crepe.npz
# 	19)	train_player-not00_solo_E-string_1.0s_crepe.npz
# 	20)	test_player-00_e-string_1.0s_crepe.npz
# 	21)	train_player-not00_e-string_1.0s_crepe.npz
# 	22)	test_player-00_B-string_1.0s_crepe.npz
# 	23)	train_player-not00_B-string_1.0s_crepe.npz
# 	24)	test_player-00_G-string_1.0s_crepe.npz
# 	25)	train_player-not00_G-string_1.0s_crepe.npz
# 	26)	test_player-00_D-string_1.0s_crepe.npz
# 	27)	train_player-not00_D-string_1.0s_crepe.npz
# 	28)	test_player-00_A-string_1.0s_crepe.npz
# 	29)	train_player-not00_A-string_1.0s_crepe.npz
# 	30)	test_player-00_E-string_1.0s_crepe.npz
# 	31)	train_player-not00_E-string_1.0s_crepe.npz
# Selection: 27
# train_player-not00_D-string_1.0s_crepe.npz

# %%
test_dataset = SingleStringDataset(loudness_stats=train_dataset.loudness_stats)
# Out:
# Type a number to select an option:
# 	0)	test_player-00_e-string.npz
# 	1)	train_player-not00_e-string.npz
# 	2)	test_player-00_E-string.npz
# 	3)	train_player-not00_E-string.npz
# 	4)	test_player-00_solo_E-string.npz
# 	5)	train_player-not00_solo_E-string.npz
# 	6)	test_player-00_solo_e-string.npz
# 	7)	train_player-not00_solo_e-string.npz
# 	8)	test_player-00_solo_e-string_1.0s_crepe.npz
# 	9)	train_player-not00_solo_e-string_1.0s_crepe.npz
# 	10)	test_player-00_solo_B-string_1.0s_crepe.npz
# 	11)	train_player-not00_solo_B-string_1.0s_crepe.npz
# 	12)	test_player-00_solo_G-string_1.0s_crepe.npz
# 	13)	train_player-not00_solo_G-string_1.0s_crepe.npz
# 	14)	test_player-00_solo_D-string_1.0s_crepe.npz
# 	15)	train_player-not00_solo_D-string_1.0s_crepe.npz
# 	16)	test_player-00_solo_A-string_1.0s_crepe.npz
# 	17)	train_player-not00_solo_A-string_1.0s_crepe.npz
# 	18)	test_player-00_solo_E-string_1.0s_crepe.npz
# 	19)	train_player-not00_solo_E-string_1.0s_crepe.npz
# 	20)	test_player-00_e-string_1.0s_crepe.npz
# 	21)	train_player-not00_e-string_1.0s_crepe.npz
# 	22)	test_player-00_B-string_1.0s_crepe.npz
# 	23)	train_player-not00_B-string_1.0s_crepe.npz
# 	24)	test_player-00_G-string_1.0s_crepe.npz
# 	25)	train_player-not00_G-string_1.0s_crepe.npz
# 	26)	test_player-00_D-string_1.0s_crepe.npz
# 	27)	train_player-not00_D-string_1.0s_crepe.npz
# 	28)	test_player-00_A-string_1.0s_crepe.npz
# 	29)	train_player-not00_A-string_1.0s_crepe.npz
# 	30)	test_player-00_E-string_1.0s_crepe.npz
# 	31)	train_player-not00_E-string_1.0s_crepe.npz
# Selection: 26
# test_player-00_D-string_1.0s_crepe.npz

# %% [markdown]
# create model

# %%
synth = DDSPMonoSynth()
# Out:
# using sweetcocoa trainable reverb.

# %% [markdown]
# create trainer

# %%
trainer = ModelTrainer(synth, train_dataset, test_dataset)

# %% [markdown]
# load checkpoint

# %%
trainer.load_checkpoint()
# Out:
# Type a number to select an option:
# 	0)	2022-07-08 08:08PM DDSP Mono Synth : training test
# 	1)	2022-07-09 01:40PM DDSP Mono Synth : load model and continue training
# 	2)	2022-07-09 11:45PM DDSP Mono Synth : resume training (third time)
# 	3)	2022-07-10 10:44AM DDSP Mono Synth : train (4th time)
# 	4)	2022-07-19 04:05PM DDSP Mono Synth Improved : synth_improvement
# 	5)	2022-07-19 06:56PM DDSP Mono Synth : train with loudness centered and 32 osc + 32 filter coeffs
# 	6)	2022-07-20 10:48AM DDSP Mono Synth : train low E
# 	7)	2022-07-20 12:24PM DDSP Mono Synth Improved : improve 32 param synth - e string
# 	8)	2022-07-20 07:03PM DDSP Mono Synth : train with lr scheduler
# 	9)	2022-07-22 11:34AM DDSP Mono Synth : train low E for a while
# 	10)	2022-07-25 06:42PM DDSP Mono Synth : train with Leaky ReLU
# 	11)	2022-07-26 04:41PM DDSP Mono Synth : try training with test dataset (one guitarist)
# 	12)	2022-07-27 06:09PM DDSP Mono Synth : folder deleting, harmonic + noise saving
# 	13)	2022-07-27 06:12PM DDSP Mono Synth : folder deleting, harmonic
# 	14)	2022-07-27 06:13PM DDSP Mono Synth : folder deleting, harm
# 	15)	2022-07-28 01:52PM DDSP Mono Synth : solo data only
# 	16)	2022-07-28 03:46PM DDSP Mono Synth : resume prev exp
# 	17)	2022-07-29 03:18PM DDSP Mono Synth : sweetcocoa mss loss
# 	18)	2022-07-29 03:56PM DDSP Mono Synth : sweetcocoa harm osc and loss
# 	19)	2022-07-29 05:58PM DDSP Mono Synth : reverb and sweetcocoa osc and loss
# 	20)	2022-08-02 01:38PM DDSP Mono Synth : sc noise, harm, reverb, and loss
# 	21)	2022-08-02 01:41PM DDSP Mono Synth : sweetcocoa harm, noise and loss no reverb
# 	22)	2022-08-02 03:36PM DDSP Mono Synth : added sweetcocoa loudness extractor
# 	23)	2022-08-02 05:47PM DDSP Mono Synth : sc reverb
# 	24)	2022-08-03 10:23AM DDSP Mono Synth : continue last and save off reverb audio
# 	25)	2022-08-03 10:32AM DDSP Mono Synth : continue again saving target audio for reverb
# 	26)	2022-08-05 04:46PM DDSP Mono Synth : train with sc components and with fixed (nonzero) loudness
# 	27)	2022-08-08 04:22PM DDSP Mono Synth : added sc decoder
# 	28)	2022-08-09 11:39AM DDSP Mono Synth : continue prev
# 	29)	2022-08-09 02:22PM DDSP Mono Synth : crepe f0 train labels
# 	30)	2022-08-09 07:36PM DDSP Mono Synth : my original code with crepe f0 labels
# 	31)	2022-08-11 01:05PM DDSP Mono Synth : train with crepe labels and my code sans reverb
# 	32)	2022-08-11 02:18PM DDSP Mono Synth : turn on sc harm osc and noise
# 	33)	2022-08-16 10:24PM DDSP Mono Synth : 1s crepe short verb, batch 64
# 	34)	2022-08-17 09:23AM DDSP Mono Synth : B string
# 	35)	2022-08-17 05:24PM DDSP Mono Synth : beta inharm
# 	36)	2022-08-17 05:58PM DDSP Mono Synth : inharm beta -10.0
# 	37)	2022-08-24 04:52PM DDSP Mono Synth : inharm beta -5
# 	38)	2022-08-25 03:06PM DDSP Mono Synth : inharm beta -20
# 	39)	2022-08-25 11:13PM DDSP Mono Synth : inharm beta -15.0
# 	40)	2022-08-26 06:00PM DDSP Mono Synth : E string
# 	41)	2022-08-26 07:19PM DDSP Mono Synth : A string
# 	42)	2022-08-26 10:54PM DDSP Mono Synth : A string
# 	43)	2022-08-29 01:02PM DDSP Mono Synth : B string
# 	44)	2022-08-30 04:33PM DDSP Mono Synth : G string
# 	45)	2022-08-30 05:29PM DDSP Mono Synth : G string
# 	46)	2022-08-31 11:44AM DDSP Mono Synth : G string
# 	47)	2022-08-31 06:38PM DDSP Mono Synth : E-string (0 inharm)
# 	48)	2022-08-31 11:31PM DDSP Mono Synth : e string, comp+solo, -1000.0 inharm
# 	49)	2022-09-01 12:22AM DDSP Mono Synth : e string, comp+solo, -1000.0 inharm
# 	50)	2022-09-01 10:48AM DDSP Mono Synth : e string, comp+solo, -1000.0 inharm
# 	51)	2022-09-01 11:38AM DDSP Mono Synth : e string, comp+solo, -1000.0 inharm
# 	52)	2022-09-01 05:32PM DDSP Mono Synth : e string
# 	53)	2022-09-01 06:27PM DDSP Mono Synth : B string
# 	54)	2022-09-02 12:19AM DDSP Mono Synth : G string
# 	55)	2022-09-02 01:09PM DDSP Mono Synth : D string
# Selection: 55
# 2022-09-02 01:09PM DDSP Mono Synth : D string
# Type a number to select an option:
# 	0)	175 epochs
# Selection: 0
# 175 epochs
# checkpoint loaded.

# %% [markdown]
# # Training

# %% [markdown]
# train model

# %%
trainer.train_model()
# Out:
# training loss: 5.275667085752382
# validation loss: 6.733574164541144
