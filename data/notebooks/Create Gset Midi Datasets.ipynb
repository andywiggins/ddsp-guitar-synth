# %% [markdown]
# # Setup

# %% [markdown]
# install requirements

# %%
# !pip install -r requirements.txt &> /dev/null

# %% [markdown]
# imports

# %%
from data.guitarset_loader import GuitarSetLoader

# %% [markdown]
# # Create Dataset Loader

# %%
loader = GuitarSetLoader()

# %% [markdown]
# # Split by player

# %%
# splits = loader.split_dataset_by_player_id(0)

# %% [markdown]
# # Optionally filter splits by version (solo or comp)

# %%
# splits = loader.filter_splits_by_version(splits, version="solo")

# %% [markdown]
# # Alternatively, manually create a split

# %%
# list_of_desired_tracks = [  "05_SS3-98-C_comp",
#                             "05_SS3-84-Bb_comp",
#                             "05_SS2-107-Ab_comp",
#                             "05_SS2-88-F_comp",
#                             "05_SS1-100-C#_comp",
#                             "05_SS1-68-E_comp",
#                             "05_BN3-154-E_comp",
#                             "05_BN3-119-G_comp",
#                             "05_BN2-166-Ab_comp",
#                             "05_BN2-131-B_comp",
#                             "05_BN1-147-Gb_comp",
#                             "05_BN1-129-Eb_comp"]

# split_name = "train_player-05_fingerstyle"

# list_of_desired_tracks = [  "00_SS3-98-C_comp",
#                             "00_SS3-84-Bb_comp",
#                             "00_SS2-107-Ab_comp",
#                             "00_SS2-88-F_comp",
#                             "00_SS1-100-C#_comp",
#                             "00_SS1-68-E_comp",
#                             "00_BN3-154-E_comp",
#                             "00_BN3-119-G_comp",
#                             "00_BN2-166-Ab_comp",
#                             "00_BN2-131-B_comp",
#                             "00_BN1-147-Gb_comp",
#                             "00_BN1-129-Eb_comp"]

# split_name = "valid_player-00_fingerstyle"

list_of_desired_tracks = [  "03_BN1-129-Eb_comp",
                            "03_BN1-147-Gb_comp",
                            "03_BN2-131-B_comp",
                            "03_BN2-166-Ab_comp",
                            "03_BN3-119-G_comp",
                            "03_BN3-154-E_comp",
                            "04_BN1-129-Eb_comp",
                            "04_BN1-147-Gb_comp",
                            "04_BN2-131-B_comp",
                            "04_BN2-166-Ab_comp",
                            "04_BN3-119-G_comp",                            
                            "04_BN3-154-E_comp",
                            "04_SS1-100-C#_comp",
                            "04_SS2-107-Ab_comp",
                            "04_SS3-98-C_comp"]

split_name = "test_players-0304_fingerstyle"



splits = {split_name : list_of_desired_tracks}

# %% [markdown]
# # Create + save datasets

# %%
loader.create_and_save_midi_conditioning_datasets_from_splits(splits, item_dur=3.0)
